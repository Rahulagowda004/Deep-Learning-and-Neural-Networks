# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('WineQT.csv')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df = df.drop(['Id'],axis = 1)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
X = df.drop(['quality'], axis = 1)
y = df['quality']

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
ss = MinMaxScaler()
X = ss.fit_transform(X)

# %%
y = ss.fit_transform(np.array(y).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size = 0.30,random_state = 1)

# %%
model = Sequential()

model.add(Dense(512, activation = 'relu', input_shape = (11,)))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.BatchNormalization())
model.add(Dense(256, activation = 'relu'))
model.add(Dense(50, activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mean_squared_error'])
# Out:
# c:\Users\rahul\Downloads\ANN\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train,y_train,epochs = 100,validation_data = (X_val,y_val))
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2596 - mean_squared_error: 0.2596 - val_loss: 0.2824 - val_mean_squared_error: 0.2824
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0933 - mean_squared_error: 0.0933 - val_loss: 0.2785 - val_mean_squared_error: 0.2785
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0568 - mean_squared_error: 0.0568 - val_loss: 0.2840 - val_mean_squared_error: 0.2840
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0531 - mean_squared_error: 0.0531 - val_loss: 0.2792 - val_mean_squared_error: 0.2792
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.2336 - val_mean_squared_error: 0.2336
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.2159 - val_mean_squared_error: 0.2159
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.2022 - val_mean_squared_error: 0.2022
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.1811 - val_mean_squared_error: 0.1811
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.1323 - val_mean_squared_error: 0.1323
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.1310 - val_mean_squared_error: 0.1310
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.1192 - val_mean_squared_error: 0.1192
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.1018 - val_mean_squared_error: 0.1018
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.1015 - val_mean_squared_error: 0.1015
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0890 - val_mean_squared_error: 0.0890
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0805 - val_mean_squared_error: 0.0805
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0659 - val_mean_squared_error: 0.0659
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0541 - val_mean_squared_error: 0.0541
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0582 - val_mean_squared_error: 0.0582
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0522 - val_mean_squared_error: 0.0522
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0394 - val_mean_squared_error: 0.0394
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0146 - val_mean_squared_error: 0.0146

# %%
plt.plot(history.history['loss'])    
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
